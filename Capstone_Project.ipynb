# %% [markdown]
# # **Project Name** - Used Car Sales EDA

# %% [markdown]
# ##### **Project Type** - Exploratory Data Analysis (EDA)
# ##### **Contribution** - Individual
# ##### **Name** - Sujal Kaler
# ##### **Section** - D2513
# ##### **Roll Number** - 07
# ##### **Reg. Number** - 12526523

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project performs Exploratory Data Analysis on a Used Car Sales dataset. The dataset contains information such as car selling price, mileage, brand, model, manufacturing year, body type, number of cylinders, drive type, engine, and location zipcode. The main aim of this project is to understand which factors affect the selling price of used cars and which car categories are most common in the market. Through data cleaning, missing value handling, feature creation, and visualization, this project identifies useful patterns such as top-selling brands, price distribution, mileage impact on price, average price by body type, and price variation by drive type. The project also uses charts like bar charts, histograms, scatter plots, box plots, pie charts, line charts, and heatmaps to present insights clearly. These insights can help buyers, sellers, and used car businesses make better pricing and inventory decisions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# GitHub Link: Add your GitHub repository link here after uploading the notebook.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The used car market has many cars with different brands, models, prices, mileage, body types, and technical features. It becomes difficult for buyers and sellers to understand which factors mainly affect the selling price. This project analyzes the used car sales dataset to find important patterns and relationships that can help in better decision-making.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective is to understand the used car market by analyzing price patterns, popular brands, mileage effect, body type demand, drive type preference, and other vehicle features. These insights can help a used car business set better prices, identify high-demand cars, and improve inventory planning.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 10 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# Display settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# This line helps charts appear inside the notebook
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# In Google Colab, upload used_car_sales.csv in /content folder before running this cell.

file_path = "/content/used_car_sales.csv"

# Load CSV file
df = pd.read_csv(file_path)

print("Dataset loaded successfully!")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print("Duplicate Rows:", duplicate_count)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
missing_values = df.isnull().sum().sort_values(ascending=False)
missing_values

# %%
# Visualizing the missing values
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0]

plt.figure(figsize=(10, 5))
missing_values.plot(kind="bar")
plt.title("Missing Values in Each Column")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains information about used cars such as selling price, mileage, make, model, year, engine, body type, number of cylinders, drive type, and zipcode. Some columns have missing values, especially Trim, Engine, BodyType, and DriveType. The dataset is useful for analyzing which car brands are popular and what factors affect used car prices.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **Variables Description:**
# - **pricesold:** Selling price of the used car.
# - **yearsold:** Year in which the car was sold/listed.
# - **zipcode:** Location zipcode.
# - **Mileage:** Distance already driven by the car.
# - **Make:** Car brand/company.
# - **Model:** Car model name.
# - **Year:** Manufacturing year of the car.
# - **Trim:** Variant/trim of the model.
# - **Engine:** Engine details.
# - **BodyType:** Type of car body such as Sedan, SUV, Coupe, etc.
# - **NumCylinders:** Number of engine cylinders.
# - **DriveType:** Type of drivetrain such as FWD, RWD, AWD, or 4WD.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in df.columns:
    print(col, ":", df[col].nunique(), "unique values")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Create a copy of the original dataset
cars = df.copy()

# Remove duplicate rows
cars = cars.drop_duplicates()

# Fill missing categorical values with "Unknown"
categorical_cols = ["zipcode", "Make", "Model", "Trim", "Engine", "BodyType", "DriveType"]
for col in categorical_cols:
    if col in cars.columns:
        cars[col] = cars[col].fillna("Unknown")

# Clean BodyType because it has many messy/special-character values
cars["BodyType"] = cars["BodyType"].astype(str).str.replace(r"[^A-Za-z0-9\s]", "", regex=True)
cars["BodyType"] = cars["BodyType"].str.strip()
cars["BodyType"] = cars["BodyType"].replace("", "Unknown")

# Create a new feature: Car_Age
# Car_Age means how old the car is compared to the selling/listing year
cars["Car_Age"] = cars["yearsold"] - cars["Year"]

# Remove unrealistic rows
cars = cars[cars["pricesold"] > 0]
cars = cars[cars["Mileage"] >= 0]
cars = cars[cars["Car_Age"] >= 0]

# Show cleaned dataset
cars.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# I removed duplicate rows, handled missing values, cleaned the BodyType column, and created a new column called Car_Age. I also removed unrealistic rows where selling price, mileage, or car age values were not valid. After cleaning, the dataset became easier to analyze and visualize. The main insight is that price, mileage, age, brand, body type, and drive type are important factors for used car analysis.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Top 10 most sold car brands

top_makes = cars["Make"].value_counts().head(10)

plt.figure(figsize=(10, 5))
top_makes.plot(kind="bar")
plt.title("Top 10 Most Sold Car Brands")
plt.xlabel("Car Brand")
plt.ylabel("Number of Cars")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because it is best for comparing categories. Here, it clearly compares the number of cars sold by each brand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the most common car brands in the dataset. Brands with higher bars have more cars listed/sold.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This helps businesses understand which brands are in high demand, so they can keep more inventory of popular brands.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Distribution of selling price

plt.figure(figsize=(10, 5))
plt.hist(cars["pricesold"], bins=30)
plt.title("Distribution of Used Car Selling Prices")
plt.xlabel("Selling Price")
plt.ylabel("Number of Cars")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used because it shows the distribution of numerical data. It helps us understand the common selling price range.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most cars are concentrated in lower and middle price ranges, while very expensive cars are fewer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This helps sellers decide price segments to focus on. Very high-priced cars may have lower demand, which can slow sales.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Mileage vs Selling Price

sample_cars = cars.sample(3000, random_state=42) if len(cars) > 3000 else cars

plt.figure(figsize=(10, 5))
plt.scatter(sample_cars["Mileage"], sample_cars["pricesold"], alpha=0.4)
plt.title("Mileage vs Selling Price")
plt.xlabel("Mileage")
plt.ylabel("Selling Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is used because it shows the relationship between two numerical variables: mileage and selling price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Cars with higher mileage generally tend to have lower selling prices, while low-mileage cars usually sell for higher prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Mileage can be used as an important pricing factor. High-mileage cars may need discounts to attract buyers.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Average price by top 10 body types

common_body_types = cars["BodyType"].value_counts().head(10).index
body_price = cars[cars["BodyType"].isin(common_body_types)].groupby("BodyType")["pricesold"].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
body_price.plot(kind="bar")
plt.title("Average Selling Price by Common Body Types")
plt.xlabel("Body Type")
plt.ylabel("Average Selling Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because body type is categorical and average selling price is numerical. This makes comparison easy.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some body types have higher average selling prices than others. This shows that vehicle style can affect resale value.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Businesses can identify profitable body types and stock cars according to customer demand and price potential.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Average price by drive type

drive_price = cars.groupby("DriveType")["pricesold"].mean().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 5))
drive_price.plot(kind="bar")
plt.title("Average Selling Price by Drive Type")
plt.xlabel("Drive Type")
plt.ylabel("Average Selling Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare average selling price across different drive types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Drive types such as AWD, RWD, FWD, or 4WD may have different average selling prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Drive type can influence customer preference and pricing strategy, especially in areas where road/weather conditions matter.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Average price by number of cylinders

cylinder_price = cars.groupby("NumCylinders")["pricesold"].mean().sort_index()

plt.figure(figsize=(10, 5))
cylinder_price.plot(kind="bar")
plt.title("Average Selling Price by Number of Cylinders")
plt.xlabel("Number of Cylinders")
plt.ylabel("Average Selling Price")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because the number of cylinders is a discrete numerical category and can be compared easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Cars with more cylinders may have higher selling prices because they are often more powerful or premium vehicles.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps sellers understand how engine power affects price. However, high-cylinder cars may also have higher fuel costs.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Average price by manufacturing year

year_price = cars.groupby("Year")["pricesold"].mean().sort_index()

plt.figure(figsize=(12, 5))
year_price.plot(kind="line", marker="o")
plt.title("Average Selling Price by Manufacturing Year")
plt.xlabel("Manufacturing Year")
plt.ylabel("Average Selling Price")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is used because manufacturing year follows a time order and we want to see the price trend over years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Newer cars generally have higher average selling prices compared to older cars.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. This helps businesses price cars based on manufacturing year. Older cars may need competitive pricing to sell faster.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Top 10 car models by count

top_models = cars["Model"].value_counts().head(10)

plt.figure(figsize=(10, 5))
top_models.plot(kind="bar")
plt.title("Top 10 Most Common Car Models")
plt.xlabel("Car Model")
plt.ylabel("Number of Cars")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because it compares the frequency of different car models.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows which car models appear most often in the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps businesses understand model-level demand and decide which models to keep in inventory.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Top 10 zipcodes by number of cars

top_zipcodes = cars["zipcode"].value_counts().head(10)

plt.figure(figsize=(10, 5))
top_zipcodes.plot(kind="bar")
plt.title("Top 10 Zipcodes by Car Count")
plt.xlabel("Zipcode")
plt.ylabel("Number of Cars")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare car counts across zipcodes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some zipcodes have more used car listings/sales than others, indicating stronger market activity in those areas.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Location-based insight helps businesses target marketing and inventory placement in active areas.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Car age distribution

plt.figure(figsize=(10, 5))
plt.hist(cars["Car_Age"], bins=30)
plt.title("Distribution of Car Age")
plt.xlabel("Car Age")
plt.ylabel("Number of Cars")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used because car age is numerical and we want to see its distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most cars are found within certain age ranges, showing which age group is common in the used car market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Businesses can understand whether customers prefer newer or older used cars. Very old cars may need lower pricing.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Price comparison of top 5 brands using box plot

top_5_makes = cars["Make"].value_counts().head(5).index
box_data = [cars[cars["Make"] == make]["pricesold"] for make in top_5_makes]

plt.figure(figsize=(10, 5))
plt.boxplot(box_data, labels=top_5_makes)
plt.title("Selling Price Comparison of Top 5 Brands")
plt.xlabel("Car Brand")
plt.ylabel("Selling Price")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is used because it shows median, spread, and outliers in selling price for each brand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows price variation among the top brands. Some brands have wider price ranges than others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps sellers understand brand-wise price variation and detect unusually high or low prices.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
# Pie chart of top 5 brands market share

top_5_makes_count = cars["Make"].value_counts().head(5)

plt.figure(figsize=(7, 7))
plt.pie(top_5_makes_count, labels=top_5_makes_count.index, autopct="%1.1f%%")
plt.title("Market Share of Top 5 Car Brands")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used to show the percentage share of the top 5 brands in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows which brands contribute the largest share among the top 5 brands.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. It helps understand brand dominance in the dataset and supports inventory planning.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Average mileage by top 10 brands

mileage_by_make = cars[cars["Make"].isin(top_makes.index)].groupby("Make")["Mileage"].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 5))
mileage_by_make.plot(kind="bar")
plt.title("Average Mileage by Top 10 Brands")
plt.xlabel("Car Brand")
plt.ylabel("Average Mileage")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare average mileage among top brands.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some brands have higher average mileage than others, which may affect their resale price.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Mileage insight can help in pricing and quality checks. High average mileage may reduce customer interest.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Correlation between numerical columns

numeric_cols = ["pricesold", "yearsold", "Mileage", "Year", "NumCylinders", "Car_Age"]
corr = cars[numeric_cols].corr()

plt.figure(figsize=(8, 6))
plt.imshow(corr, aspect="auto")
plt.colorbar(label="Correlation")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.columns)), corr.columns)
plt.title("Correlation Heatmap")

# Show correlation values inside the heatmap
for i in range(len(corr.columns)):
    for j in range(len(corr.columns)):
        plt.text(j, i, round(corr.iloc[i, j], 2), ha="center", va="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used because it quickly shows relationships between numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap helps identify how selling price is related to mileage, year, car age, and cylinders.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
# Using scatter matrix as a simple pair plot alternative

pair_cols = ["pricesold", "Mileage", "Year", "NumCylinders", "Car_Age"]
pair_sample = cars[pair_cols].sample(1000, random_state=42) if len(cars) > 1000 else cars[pair_cols]

scatter_matrix(pair_sample, figsize=(10, 10), diagonal="hist", alpha=0.4)
plt.suptitle("Pair Plot of Important Numerical Variables", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used because it shows multiple numerical relationships together in one visual.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It helps compare price, mileage, manufacturing year, cylinders, and car age at the same time.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective, the client should focus on brands and models with higher demand, use mileage and manufacturing year as key pricing factors, and maintain inventory according to body type and drive type preferences. Cars with low mileage and newer manufacturing years can be priced higher, while older or high-mileage cars should be priced more competitively. The business should also focus marketing efforts on active zipcodes where more used car sales are found.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This EDA project analyzed the used car sales dataset using different charts and data cleaning techniques. The analysis showed that car selling price is influenced by factors such as brand, mileage, manufacturing year, body type, drive type, number of cylinders, and car age. Bar charts helped identify popular brands and models, histograms showed price and age distribution, scatter plots showed the relationship between mileage and price, and correlation analysis helped understand numerical relationships. Overall, the project provides useful insights that can help used car businesses make better decisions about pricing, inventory planning, and customer targeting.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
